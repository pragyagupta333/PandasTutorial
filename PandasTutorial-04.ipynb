# %% [markdown]
# # Creating Plots In Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/PRAGYA GUPTA/OneDrive/Documents/MyProjects/PandasTutorial/csvFile/Plot_Data.csv")

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # Visual Check Of Data

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plot Only Calories Data

# %%
data['Calories'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plot
#
# #### Create Scatter Plot with Duration As X-axis And Calories as Y-axis

# %% [markdown]
# The kind argument specifies type of plot you want to create.

# %%
data.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %% [markdown]
# So, We can conclude that higher the duration,more the calories burned

# %% [markdown]
# In many development environments as well as IPython and Jupyter Notebook, use the TAB button to get an overview of the available methods, for example data.plot. + TAB.

# %% [markdown]
# # Histogram

# %% [markdown]
# #### A histogram needs only one column.
#
# #### Create a Histogram Which Shows : How Many Workouts Burned Calories Between 250 to 500 units

# %%
data["Calories"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# The Histogram Tells That Over 100 Workouts Burned Calories Between 250 to 500 units

# %% [markdown]
# # Show each of the columns in a separate subplot.

# %% [markdown]
# Separate subplots for each of the data columns are supported by the subplots argument of the plot functions.

# %%
data.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# # Plot Area Graph For DataFrame

# %%
data.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Set label/name for axis and save the graph figure

# %%
fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty Matplotlib Figure and Axes
data.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("y-axis-label")          # Do any Matplotlib customization you like
fig.savefig("Graph.png")           # Save the Figure/Axes using the existing Matplotlib method.
plt.show()                                      # Display the plot

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# ## Plot Bar Graph For 4th Row (row stars from 0)

# %%
data.iloc[4].plot(kind="bar");

# %% [markdown]
# ## What Is The Ratio Of Calories Burned To Duration Of Workout? Store Result In Separate Column

# %%
data['Calories_duration_ratio'] = data['Calories']/data['Duration']

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories  Calories_duration_ratio
# 0        60    110       130     409.1                 6.818333
# 1        60    117       145     479.0                 7.983333
# 2        60    103       135     340.0                 5.666667
# 3        45    109       175     282.4                 6.275556
# 4        45    117       148     406.0                 9.022222

# %% [markdown]
# # Rename Column 'Calories_duration_ratio' TO 'Ratio_Calories_duration'

# %%
data_renamed = data.rename( columns={'Calories_duration_ratio':'Ratio_Calories_duration'})

# %%
data_renamed
# Out:
#      Duration  Pulse  Maxpulse  Calories  Ratio_Calories_duration
# 0          60    110       130     409.1                 6.818333
# 1          60    117       145     479.0                 7.983333
# 2          60    103       135     340.0                 5.666667
# 3          45    109       175     282.4                 6.275556
# 4          45    117       148     406.0                 9.022222
# ..        ...    ...       ...       ...                      ...
# 164        60    105       140     290.8                 4.846667
# 165        60    110       145     300.0                 5.000000
# 166        60    115       145     310.2                 5.170000
# 167        75    120       150     320.4                 4.272000
# 168        75    125       150     330.4                 4.405333
#
# [169 rows x 5 columns]

# %% [markdown]
# #### ~ Pragya 🎀
